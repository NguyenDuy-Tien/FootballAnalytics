# %% [markdown]
# ## Reading the dataset

# %%
import numpy as np
import pandas as pd

#Reading the dataset
dataset = pd.read_excel("../GK-data.xlsx")

# %% [markdown]
# ## Spliting dataset into train set and test set

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(dataset, test_size=0.2)
print("Train set:\n", train)
print("Test set:\n", test)
# Out:
# Train set:
#        Rk            Player  Nation Pos         Squad                Comp  \
# 126   56  Samir Handanović  si SVN  GK         Inter          it Serie A
# 23   125       Brice Samba  cg CGO  GK          Lens          fr Ligue 1
# 15    72     Anthony Lopes  pt POR  GK          Lyon          fr Ligue 1
# 53    71       Hugo Lloris  fr FRA  GK     Tottenham  eng Premier League
# 98   130         Matz Sels  be BEL  GK    Strasbourg          fr Ligue 1
# ..   ...               ...     ...  ..           ...                 ...
# 43   123   Frederik Rønnow  dk DEN  GK  Union Berlin       de Bundesliga
# 54    87     Illan Meslier  fr FRA  GK  Leeds United  eng Premier League
# 47   106   Gianluca Pegolo  it ITA  GK      Sassuolo          it Serie A
# 74    22     Koen Casteels  be BEL  GK     Wolfsburg       de Bundesliga
# 94   128    Marvin Schwäbe  de GER  GK          Köln       de Bundesliga
#
#         Age  Born   90s  GA  ...  GoalKicksAtt  GoalKicksLaunch%  \
# 126  38-188  1984   8.0  13  ...            45               4.4
# 23   28-268  1994  19.0  13  ...            74              27.0
# 15   32-109  1990  15.3  19  ...            95              22.1
# 53   36-023  1986  18.0  25  ...           138              20.3
# 98   30-326  1992  19.0  34  ...           101              53.5
# ..      ...   ...   ...  ..  ...           ...               ...
# 43   30-167  1992  11.0   9  ...            68              61.8
# 54   22-322  2000  18.0  33  ...           138              53.6
# 47   41-299  1981   1.0   2  ...            10              20.0
# 74   30-207  1992  15.0  20  ...           146              56.2
# 94   27-268  1995  15.0  29  ...            87              28.7
#
#      GoalKicksAvgLen  Opp  Stp  Stp%  #OPA  #OPA/90  AvgDist  rating
# 126             24.0   79    2   2.5     5     0.63     14.6    6.65
# 23              28.2  190   17   8.9    25     1.32     16.1    6.83
# 15              27.6  162    8   4.9    10     0.65     13.4    6.57
# 53              23.8  220   14   6.4    24     1.33     14.4    6.67
# 98              43.3  283   20   7.1    20     1.05     11.9    6.67
# ..               ...  ...  ...   ...   ...      ...      ...     ...
# 43              48.6  160   16  10.0    10     0.91     12.3    7.02
# 54              42.5  220   18   8.2    35     1.94     16.6    6.70
# 47              24.0    6    0   0.0     0     0.00     13.0    5.81
# 74              46.9  220   11   5.0    20     1.33     16.1    6.98
# 94              33.6  195    8   4.1     7     0.47     11.6    6.26
#
# [117 rows x 35 columns]
# Test set:
#        Rk                     Player  Nation Pos            Squad  \
# 49    78       Giorgi Mamardashvili  ge GEO  GK         Valencia
# 19    69             Benjamin Leroy  fr FRA  GK          Ajaccio
# 92   146               Mark Travers  ie IRL  GK      Bournemouth
# 142   45               Yahia Fofana  fr FRA  GK           Angers
# 76    90            Lorenzo Montipò  it ITA  GK    Hellas Verona
# 17    36       Bartłomiej Drągowski  pl POL  GK           Spezia
# 27    49               David de Gea  es ESP  GK   Manchester Utd
# 1     81          Agustín Marchesín  ar ARG  GK       Celta Vigo
# 69    19                Juan Carlos  es ESP  GK           Girona
# 109   74                  Pau López  es ESP  GK        Marseille
# 131  147               Sven Ulreich  de GER  GK    Bayern Munich
# 58    61       Jan Jakob Olschowsky  de GER  GK       M'Gladbach
# 9      2                    Alisson  br BRA  GK        Liverpool
# 116  114           Predrag Rajković  rs SRB  GK         Mallorca
# 100   30        Michele Di Gregorio  it ITA  GK            Monza
# 21    68                 Bernd Leno  de GER  GK           Fulham
# 57    52                  Ivo Grbić  hr CRO  GK  Atlético Madrid
# 88   133            Marco Silvestri  it ITA  GK          Udinese
# 10    42           Álvaro Fernández  es ESP  GK         Espanyol
# 41   137  François-Joseph Sollacaro  fr FRA  GK          Ajaccio
# 97   108               Mattia Perin  it ITA  GK         Juventus
# 118   29              Rémy Descamps  fr FRA  GK           Nantes
# 121  100                Robin Olsen  se SWE  GK      Aston Villa
# 28   116                 David Raya  es ESP  GK        Brentford
# 113   55              Péter Gulácsi  hu HUN  GK       RB Leipzig
# 25    17              Claudio Bravo  cl CHI  GK            Betis
# 55   113                 Ionuț Radu  ro ROU  GK        Cremonese
# 2     41            Aitor Fernández  es ESP  GK          Osasuna
# 125  132                  Rui Silva  pt POR  GK            Betis
# 123   13               Rubén Blanco  es ESP  GK        Marseille
#
#                    Comp     Age  Born   90s  GA  ...  GoalKicksAtt  \
# 49           es La Liga  22-111  2000  16.0  18  ...            77
# 19           fr Ligue 1  33-286  1989  17.1  31  ...           110
# 92   eng Premier League  23-245  1999  10.5  31  ...           109
# 142          fr Ligue 1  22-150  2000   8.0  15  ...            53
# 76           it Serie A  26-332  1996  18.0  31  ...           146
# 17           it Serie A  25-152  1997  15.5  25  ...            93
# 27   eng Premier League  32-072  1990  18.0  21  ...            89
# 1            es La Liga  34-308  1988  17.0  28  ...           120
# 69           es La Liga  34-363  1988  10.0  18  ...            62
# 109          fr Ligue 1  28-036  1994  16.0  12  ...            87
# 131       de Bundesliga  34-168  1988   3.0   2  ...            18
# 58        de Bundesliga  21-061  2001   2.0   4  ...            13
# 9    eng Premier League  30-108  1992  18.0  25  ...            90
# 116          es La Liga  27-079  1995  17.0  16  ...           162
# 100          it Serie A  25-175  1997  18.0  27  ...           108
# 21   eng Premier League  30-320  1992  18.0  27  ...           125
# 57           es La Liga  27-000  1996   2.3   2  ...            23
# 88           it Serie A  31-322  1991  18.0  21  ...           146
# 10           es La Liga  24-280  1998   7.0  11  ...            71
# 41           fr Ligue 1  28-303  1994   1.0   3  ...             3
# 97           it Serie A  30-069  1992   6.5   4  ...            41
# 118          fr Ligue 1  26-207  1996   1.0   1  ...             6
# 121  eng Premier League  33-010  1990   2.6   7  ...            24
# 28   eng Premier League  27-125  1995  19.0  28  ...           147
# 113       de Bundesliga  32-257  1990   6.0  10  ...            36
# 25           es La Liga  39-280  1983   2.0   1  ...            20
# 55           it Serie A  25-235  1997   9.0  19  ...            67
# 2            es La Liga  31-260  1991   7.0   5  ...            50
# 125          es La Liga  28-345  1994  14.0  12  ...           120
# 123          fr Ligue 1  27-177  1995   3.0   4  ...            28
#
#      GoalKicksLaunch%  GoalKicksAvgLen  Opp  Stp  Stp%  #OPA  #OPA/90  \
# 49               39.0             36.3  185   13   7.0    23     1.44
# 19               80.0             50.8  200   10   5.0    29     1.70
# 92               58.7             45.7  206    5   2.4     4     0.38
# 142              49.1             41.0  105   11  10.5     5     0.63
# 76               56.2             43.9  243    8   3.3    44     2.44
# 17               65.6             49.6  220    9   4.1    21     1.36
# 27               67.4             49.8  272    8   2.9    16     0.89
# 1                51.7             43.0  228   12   5.3    24     1.41
# 69               24.2             30.3  120    6   5.0    21     2.10
# 109              50.6             39.9  178   11   6.2    21     1.31
# 131              16.7             23.4   34    2   5.9     4     1.33
# 58                7.7             22.2   30    2   6.7     3     1.50
# 9                23.3             30.9  202    6   3.0    36     2.00
# 116              66.0             48.8  271   11   4.1    10     0.59
# 100              31.5             31.7  237    8   3.4    10     0.56
# 21               39.2             35.8  232   20   8.6    23     1.28
# 57               95.7             67.0   43    7  16.3     0     0.00
# 88               39.0             36.4  235    4   1.7     9     0.50
# 10               81.7             56.3  103    3   2.9     8     1.14
# 41                0.0             23.0   10    0   0.0     0     0.00
# 97               39.0             35.3   99    2   2.0     9     1.38
# 118              66.7             46.5   11    1   9.1     0     0.00
# 121              58.3             46.1   38    4  10.5     3     1.14
# 28               72.1             52.9  306   26   8.5    27     1.42
# 113              25.0             29.6   61    3   4.9    10     1.67
# 25               95.0             62.3   30    0   0.0     2     1.00
# 55               50.7             46.3  107    6   5.6     9     1.00
# 2                70.0             51.7   89    4   4.5    13     1.86
# 125              66.7             49.5  193   10   5.2    24     1.71
# 123              42.9             35.5   45    0   0.0     4     1.33
#
#      AvgDist  rating
# 49      16.6    6.65
# 19      16.6    6.29
# 92       9.6    6.25
# 142     12.0    6.54
# 76      17.7    6.65
# 17      15.6    6.74
# 27      15.9    6.65
# 1       18.4    6.53
# 69      16.9    6.33
# 109     15.9    6.94
# 131     17.5    6.78
# 58      14.1    6.48
# 9       20.2    6.97
# 116     12.4    6.65
# 100     13.2    6.63
# 21      14.2    7.15
# 57       5.5    6.73
# 88      13.8    6.53
# 10      15.4    6.43
# 41      14.7    5.38
# 97      17.8    6.90
# 118      7.0    6.69
# 121     16.2    6.86
# 28      15.7    6.98
# 113     19.4    6.54
# 25      15.7    6.93
# 55      14.5    6.88
# 2       16.4    6.82
# 125     16.6    6.74
# 123     20.3    6.32
#
# [30 rows x 35 columns]

# %% [markdown]
# ## Putting dataset through a Linear Regression model
# Apps field is removed due to high correlation with minutesPlayed
#
# Name and team field is removed since they have no relationship with a player's rating

# %%
from sklearn.neighbors import KNeighborsRegressor

input_columns = ['90s','GA','PKA','FK','CK', 'OG', 'PSxG', 'PSxG/SoT', 'PSxG+/-', '/90', 'Cmp',
                 'LaunchedAtt', 'Cmp%', 'PassesAtt', 'Thr', 'PassesLaunch%', 'PassesAvgLen', 'GoalKicksAtt',
                  'GoalKicksLaunch%', 'GoalKicksAvgLen', 'Opp', 'Stp', 'Stp%', '#OPA', '#OPA/90', 'AvgDist']
output_column = ['rating']

X_train = train[input_columns]
Y_train = train[output_column]
X_test = test[input_columns]
Y_test = test[output_column]

model = KNeighborsRegressor(n_neighbors=5)
model.fit(X_train, Y_train)
print('Test R^2     : %.3f'%model.score(X_test, Y_test))
print('Training R^2 : %.3f'%model.score(X_train, Y_train))
# Out:
# Test R^2     : 0.346
# Training R^2 : 0.116

# %% [markdown]
# ## Try to apply the model on the whole dataset to predict Yashin Trophy winner

# %%
X_dataset = dataset[input_columns]
Y_preds = model.predict(X_dataset)
dataset['preds'] = Y_preds

yashin_winner = dataset.sort_values(['preds'],ascending=False)[:10]
print(yashin_winner[['Player', 'rating', 'preds']])
# Out:
#                Player  rating  preds
# 63      Jiří Pavlenka    6.61  6.822
# 72  Kepa Arrizabalaga    7.16  6.816
# 4          Alex Meret    6.65  6.814
# 73        Kevin Trapp    6.37  6.812
# 65        Jonas Omlin    6.68  6.812
# 59          Jan Oblak    6.89  6.812
# 54      Illan Meslier    6.70  6.808
# 44    Gauthier Gallon    6.35  6.796
# 82       Manuel Neuer    6.82  6.790
# 32      Doğan Alemdar    6.81  6.786
