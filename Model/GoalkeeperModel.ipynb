# %% [markdown]
# ## Reading the dataset

# %%
import numpy as np
import pandas as pd

#Reading the dataset
dataset = pd.read_excel("./GK-data.xlsx")

# %% [markdown]
# ## Spliting dataset into train set and test set

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(dataset, test_size=0.1)
print("Train set:\n", train)
print("Test set:\n", test)
# Out:
# Train set:
#        Rk                Player  Nation Pos            Squad           Comp  \
# 7     96       Alexander Nübel  de GER  GK           Monaco     fr Ligue 1
# 48    35  Gianluigi Donnarumma  it ITA  GK        Paris S-G     fr Ligue 1
# 73   145           Kevin Trapp  de GER  GK   Eint Frankfurt  de Bundesliga
# 17    36  Bartłomiej Drągowski  pl POL  GK           Spezia     it Serie A
# 142   45          Yahia Fofana  fr FRA  GK           Angers     fr Ligue 1
# ..   ...                   ...     ...  ..              ...            ...
# 143  138           Yann Sommer  ch SUI  GK       M'Gladbach  de Bundesliga
# 59    98             Jan Oblak  si SVN  GK  Atlético Madrid     es La Liga
# 65   101           Jonas Omlin  ch SUI  GK      Montpellier     fr Ligue 1
# 29   139           David Soria  es ESP  GK           Getafe     es La Liga
# 145   33         Yehvann Diouf  fr FRA  GK            Reims     fr Ligue 1
#
#         Age  Born   90s  GA  ...  GoalKicksAtt  GoalKicksLaunch%  \
# 7    26-110  1996  19.0  26  ...           137              65.0
# 48   23-327  1999  19.0  14  ...            94              18.1
# 73   32-194  1990  15.0  24  ...           101              41.6
# 17   25-152  1997  15.5  25  ...            93              65.6
# 142  22-150  2000   8.0  15  ...            53              49.1
# ..      ...   ...   ...  ..  ...           ...               ...
# 143  34-032  1988  10.0  14  ...            90              24.4
# 59   30-011  1993  14.7  14  ...           108              59.3
# 65   29-008  1994  13.0  26  ...            85              64.7
# 29   29-289  1993  17.0  24  ...           144              84.7
# 145  23-063  1999  12.0   9  ...            80              48.8
#
#      GoalKicksAvgLen  Opp  Stp  Stp%  #OPA  #OPA/90  AvgDist  rating
# 7               45.8  232   14   6.0    19     1.00     13.7    6.86
# 48              24.1  174   14   8.0    18     0.95     14.5    7.04
# 73              39.8  195    9   4.6     9     0.60     13.1    6.37
# 17              49.6  220    9   4.1    21     1.36     15.6    6.74
# 142             41.0  105   11  10.5     5     0.63     12.0    6.54
# ..               ...  ...  ...   ...   ...      ...      ...     ...
# 143             28.6  162    5   3.1    13     1.30     14.6    7.13
# 59              46.0  190   10   5.3    11     0.75     16.2    6.89
# 65              47.3  209   14   6.7    12     0.93     12.0    6.68
# 29              56.5  277   13   4.7    22     1.29     16.0    6.69
# 145             40.4  203   19   9.4    11     0.92     11.9    7.12
#
# [132 rows x 35 columns]
# Test set:
#        Rk                Player  Nation Pos           Squad  \
# 146   93            Yvon Mvogo  ch SUI  GK         Lorient
# 116  114      Predrag Rajković  rs SRB  GK        Mallorca
# 34     7           Édgar Badía  es ESP  GK           Elche
# 13    76         Andrey Lunyov  ru RUS  GK      Leverkusen
# 6     88       Alexander Meyer  de GER  GK        Dortmund
# 110   11       Paul Bernardoni  fr FRA  GK          Angers
# 90   121           Marek Rodák  sk SVK  GK          Fulham
# 9      2               Alisson  br BRA  GK       Liverpool
# 141  141     Wojciech Szczęsny  pl POL  GK        Juventus
# 11   102           André Onana  cm CMR  GK           Inter
# 140   40     Wladimiro Falcone  it ITA  GK           Lecce
# 1     81     Agustín Marchesín  ar ARG  GK      Celta Vigo
# 118   29         Rémy Descamps  fr FRA  GK          Nantes
# 31    73           Diego López  es ESP  GK  Rayo Vallecano
# 49    78  Giorgi Mamardashvili  ge GEO  GK        Valencia
#
#                    Comp     Age  Born   90s  GA  ...  GoalKicksAtt  \
# 146          fr Ligue 1  28-226  1994  13.1  19  ...           105
# 116          es La Liga  27-079  1995  17.0  16  ...           162
# 34           es La Liga  30-340  1992  17.0  35  ...           130
# 13        de Bundesliga  31-066  1991   1.0   2  ...             3
# 6         de Bundesliga  31-280  1991   4.0   8  ...            28
# 110          fr Ligue 1  25-275  1997  11.0  26  ...            75
# 90   eng Premier League  26-036  1996   2.0   2  ...            15
# 9    eng Premier League  30-108  1992  18.0  25  ...            90
# 141          it Serie A  32-275  1990  11.5   8  ...            54
# 11           it Serie A  26-291  1996  10.0  11  ...            74
# 140          it Serie A  27-281  1995  18.0  20  ...           144
# 1            es La Liga  34-308  1988  17.0  28  ...           120
# 118          fr Ligue 1  26-207  1996   1.0   1  ...             6
# 31           es La Liga  41-076  1981   1.0   3  ...             8
# 49           es La Liga  22-111  2000  16.0  18  ...            77
#
#      GoalKicksLaunch%  GoalKicksAvgLen  Opp  Stp  Stp%  #OPA  #OPA/90  \
# 146              57.1             41.8  278   13   4.7     7     0.53
# 116              66.0             48.8  271   11   4.1    10     0.59
# 34               56.9             43.3  255    9   3.5     5     0.29
# 13                0.0             15.3    6    1  16.7     1     1.00
# 6                25.0             32.1   39    4  10.3    14     3.50
# 110              41.3             38.6  136   10   7.4     9     0.82
# 90               86.7             60.0   26    1   3.8     2     1.00
# 9                23.3             30.9  202    6   3.0    36     2.00
# 141              46.3             41.9  144    4   2.8     6     0.52
# 11               37.8             38.9  142    6   4.2     3     0.30
# 140              77.1             52.3  278   13   4.7    19     1.06
# 1                51.7             43.0  228   12   5.3    24     1.41
# 118              66.7             46.5   11    1   9.1     0     0.00
# 31               25.0             35.3   12    0   0.0     2     2.00
# 49               39.0             36.3  185   13   7.0    23     1.44
#
#      AvgDist  rating
# 146     10.2    6.65
# 116     12.4    6.65
# 34      11.2    6.65
# 13      13.0    6.06
# 6       21.9    6.40
# 110     12.4    6.48
# 90      14.0    6.22
# 9       20.2    6.97
# 141     13.5    6.94
# 11      14.2    6.65
# 140     12.3    6.76
# 1       18.4    6.53
# 118      7.0    6.69
# 31      17.0    4.63
# 49      16.6    6.65
#
# [15 rows x 35 columns]

# %% [markdown]
# ## Putting dataset through a Linear Regression model
# Apps field is removed due to high correlation with minutesPlayed
#
# Name and team field is removed since they have no relationship with a player's rating

# %%
from sklearn.linear_model import LinearRegression

input_columns = ['90s','GA','PKA','FK','CK', 'OG', 'PSxG', 'PSxG/SoT', 'PSxG+/-', '/90', 'Cmp', 'LaunchedAtt', 'Cmp%', 'PassesAtt', 'Thr', 'PassesLaunch%', 'PassesAvgLen', 'GoalKicksAtt', 'GoalKicksLaunch%', 'GoalKicksAvgLen', 'Opp', 'Stp', 'Stp%', '#OPA', '#OPA/90', 'AvgDist']
output_column = ['rating']

X_train = train[input_columns]
Y_train = train[output_column]
X_test = test[input_columns]
Y_test = test[output_column]

model = LinearRegression()
model.fit(X_train, Y_train)
print('Test R^2     : %.3f'%model.score(X_test, Y_test))
print('Training R^2 : %.3f'%model.score(X_train, Y_train))
# Out:
# Test R^2     : 0.734
# Training R^2 : 0.683

# %% [markdown]
# ## Try to apply the model on the whole dataset to predict Yashin Trophy winner

# %%
X_dataset = dataset[input_columns]
Y_preds = model.predict(X_dataset)
dataset['preds'] = Y_preds

yashin_winner = dataset.sort_values(['preds'],ascending=False)[:10]
print(yashin_winner[['Player', 'rating', 'preds']])
# Out:
#                 Player  rating     preds
# 16       Asmir Begović    7.82  7.273042
# 145      Yehvann Diouf    7.12  7.166469
# 64    Joaquín Blázquez    7.19  7.137352
# 51   Guglielmo Vicario    6.95  7.077038
# 9              Alisson    6.97  7.076746
# 117    Rafał Gikiewicz    7.17  7.054036
# 57           Ivo Grbić    6.73  7.046379
# 46      Gerónimo Rulli    7.14  7.033369
# 21          Bernd Leno    7.15  7.029138
# 107       Ørjan Nyland    6.87  7.021149
