# %% [markdown]
# ## Reading the dataset

# %%
import numpy as np
import pandas as pd

#Reading the dataset
dataset = pd.read_excel("../GK-data.xlsx")

# %% [markdown]
# ## Spliting dataset into train set and test set

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(dataset, test_size=0.2)
print("Train set:\n", train)
print("Test set:\n", test)
# Out:
# Train set:
#        Rk                Player  Nation Pos            Squad           Comp  \
# 47   106       Gianluca Pegolo  it ITA  GK         Sassuolo     it Serie A
# 88   133       Marco Silvestri  it ITA  GK          Udinese     it Serie A
# 79    60        Lukáš Hrádecký  fi FIN  GK       Leverkusen  de Bundesliga
# 89   140      Marco Sportiello  it ITA  GK         Atalanta     it Serie A
# 17    36  Bartłomiej Drągowski  pl POL  GK           Spezia     it Serie A
# ..   ...                   ...     ...  ..              ...            ...
# 101   77          Mike Maignan  fr FRA  GK            Milan     it Serie A
# 86    12           Marco Bizot  nl NED  GK            Brest     fr Ligue 1
# 49    78  Giorgi Mamardashvili  ge GEO  GK         Valencia     es La Liga
# 57    52             Ivo Grbić  hr CRO  GK  Atlético Madrid     es La Liga
# 51   148     Guglielmo Vicario  it ITA  GK           Empoli     it Serie A
#
#         Age  Born   90s  GA  ...  GoalKicksAtt  GoalKicksLaunch%  \
# 47   41-299  1981   1.0   2  ...            10              20.0
# 88   31-322  1991  18.0  21  ...           146              39.0
# 79   33-055  1989  14.0  24  ...            87              47.1
# 89   30-253  1992   6.9   9  ...            61              68.9
# 17   25-152  1997  15.5  25  ...            93              65.6
# ..      ...   ...   ...  ..  ...           ...               ...
# 101  27-199  1995   7.0   8  ...            18              38.9
# 86   31-314  1991  18.0  34  ...           135              50.4
# 49   22-111  2000  16.0  18  ...            77              39.0
# 57   27-000  1996   2.3   2  ...            23              95.7
# 51   26-103  1996  18.0  22  ...            96              45.8
#
#      GoalKicksAvgLen  Opp  Stp  Stp%  #OPA  #OPA/90  AvgDist  rating
# 47              24.0    6    0   0.0     0     0.00     13.0    5.81
# 88              36.4  235    4   1.7     9     0.50     13.8    6.53
# 79              40.5  154    9   5.8    12     0.86     14.5    6.45
# 89              48.9   86    7   8.1    14     2.02     19.9    6.28
# 17              49.6  220    9   4.1    21     1.36     15.6    6.74
# ..               ...  ...  ...   ...   ...      ...      ...     ...
# 101             40.4   65    5   7.7     6     0.86     12.9    6.75
# 86              41.6  231    9   3.9    12     0.67     11.9    6.65
# 49              36.3  185   13   7.0    23     1.44     16.6    6.65
# 57              67.0   43    7  16.3     0     0.00      5.5    6.73
# 51              41.7  375   25   6.7     8     0.44     10.6    6.95
#
# [117 rows x 35 columns]
# Test set:
#        Rk                     Player  Nation Pos           Squad  \
# 127    5              Sergio Asenjo  es ESP  GK      Valladolid
# 141  141          Wojciech Szczęsny  pl POL  GK        Juventus
# 11   102                André Onana  cm CMR  GK           Inter
# 146   93                 Yvon Mvogo  ch SUI  GK         Lorient
# 36     6                Emil Audero  it ITA  GK       Sampdoria
# 53    71                Hugo Lloris  fr FRA  GK       Tottenham
# 105    8             Oliver Baumann  de GER  GK      Hoffenheim
# 61    67           Jeremías Ledesma  ar ARG  GK           Cádiz
# 28   116                 David Raya  es ESP  GK       Brentford
# 111   48            Paulo Gazzaniga  ar ARG  GK          Girona
# 69    19                Juan Carlos  es ESP  GK          Girona
# 4     86                 Alex Meret  it ITA  GK          Napoli
# 137   54             Vicente Guaita  es ESP  GK  Crystal Palace
# 134   64               Tomáš Koubek  cz CZE  GK        Augsburg
# 145   33              Yehvann Diouf  fr FRA  GK           Reims
# 93    34            Marko Dmitrović  rs SRB  GK         Sevilla
# 64    15           Joaquín Blázquez  ar ARG  GK           Brest
# 78   131                 Luigi Sepe  it ITA  GK     Salernitana
# 87    20          Marco Carnesecchi  it ITA  GK       Cremonese
# 117   50            Rafał Gikiewicz  pl POL  GK        Augsburg
# 10    42           Álvaro Fernández  es ESP  GK        Espanyol
# 75    53              Lennart Grill  de GER  GK    Union Berlin
# 32     1              Doğan Alemdar  tr TUR  GK          Rennes
# 41   137  François-Joseph Sollacaro  fr FRA  GK         Ajaccio
# 95    70                Mateusz Lis  pl POL  GK          Troyes
# 20    27              Benoît Costil  fr FRA  GK         Auxerre
# 6     88            Alexander Meyer  de GER  GK        Dortmund
# 19    69             Benjamin Leroy  fr FRA  GK         Ajaccio
# 23   125                Brice Samba  cg CGO  GK            Lens
# 130   32         Stole Dimitrievski  mk MKD  GK  Rayo Vallecano
#
#                    Comp     Age  Born   90s  GA  ...  GoalKicksAtt  \
# 127          es La Liga  33-204  1989   5.0   7  ...            49
# 141          it Serie A  32-275  1990  11.5   8  ...            54
# 11           it Serie A  26-291  1996  10.0  11  ...            74
# 146          fr Ligue 1  28-226  1994  13.1  19  ...           105
# 36           it Serie A  26-000  1997  18.0  31  ...           137
# 53   eng Premier League  36-023  1986  18.0  25  ...           138
# 105       de Bundesliga  32-230  1990  15.0  22  ...           103
# 61           es La Liga  29-339  1993  17.0  28  ...           147
# 28   eng Premier League  27-125  1995  19.0  28  ...           147
# 111          es La Liga  31-016  1992   7.0   9  ...            56
# 69           es La Liga  34-363  1988  10.0  18  ...            62
# 4            it Serie A  25-302  1997  18.0  14  ...           112
# 137  eng Premier League  36-008  1987  18.0  26  ...           137
# 134       de Bundesliga  30-145  1992   4.0   9  ...            40
# 145          fr Ligue 1  23-063  1999  12.0   9  ...            80
# 93           es La Liga  30-359  1992   2.5   3  ...            18
# 64           fr Ligue 1  21-355  2001   1.0   0  ...            11
# 78           it Serie A  31-255  1991  15.0  24  ...           134
# 87           it Serie A  22-201  2000   9.0  13  ...            53
# 117       de Bundesliga  35-084  1987  11.0  17  ...           120
# 10           es La Liga  24-280  1998   7.0  11  ...            71
# 75        de Bundesliga  23-358  1999   4.0  11  ...            11
# 32           fr Ligue 1  20-081  2002   2.5   4  ...            19
# 41           fr Ligue 1  28-303  1994   1.0   3  ...             3
# 95           fr Ligue 1  25-325  1997   7.0  14  ...            65
# 20           fr Ligue 1  35-199  1987  19.0  41  ...           137
# 6         de Bundesliga  31-280  1991   4.0   8  ...            28
# 19           fr Ligue 1  33-286  1989  17.1  31  ...           110
# 23           fr Ligue 1  28-268  1994  19.0  13  ...            74
# 130          es La Liga  29-024  1993  16.0  17  ...           131
#
#      GoalKicksLaunch%  GoalKicksAvgLen  Opp  Stp  Stp%  #OPA  #OPA/90  \
# 127              71.4             52.6   77    2   2.6    13     2.60
# 141              46.3             41.9  144    4   2.8     6     0.52
# 11               37.8             38.9  142    6   4.2     3     0.30
# 146              57.1             41.8  278   13   4.7     7     0.53
# 36               58.4             44.9  231   14   6.1    17     0.94
# 53               20.3             23.8  220   14   6.4    24     1.33
# 105              17.5             25.0  178   20  11.2    21     1.40
# 61               88.4             64.4  308   21   6.8     6     0.35
# 28               72.1             52.9  306   26   8.5    27     1.42
# 111              53.6             46.4  109   10   9.2    17     2.43
# 69               24.2             30.3  120    6   5.0    21     2.10
# 4                20.5             27.3  190    6   3.2    21     1.17
# 137              43.8             34.4  290   21   7.2    22     1.22
# 134              85.0             60.0   80    6   7.5     2     0.50
# 145              48.8             40.4  203   19   9.4    11     0.92
# 93               55.6             51.0   35    6  17.1     3     1.20
# 64               18.2             26.3   11    2  18.2     0     0.00
# 78               46.3             40.6  199   15   7.5    11     0.73
# 87               54.7             48.2   94    6   6.4     7     0.78
# 117              78.3             56.0  183   12   6.6    18     1.64
# 10               81.7             56.3  103    3   2.9     8     1.14
# 75               90.9             60.6   34    7  20.6     5     1.25
# 32               52.6             42.0   40    2   5.0     3     1.20
# 41                0.0             23.0   10    0   0.0     0     0.00
# 95               40.0             34.1  129   10   7.8    11     1.57
# 20               74.5             51.7  285    3   1.1    11     0.58
# 6                25.0             32.1   39    4  10.3    14     3.50
# 19               80.0             50.8  200   10   5.0    29     1.70
# 23               27.0             28.2  190   17   8.9    25     1.32
# 130              56.5             46.1  216    5   2.3    24     1.50
#
#      AvgDist  rating
# 127     18.9    5.83
# 141     13.5    6.94
# 11      14.2    6.65
# 146     10.2    6.65
# 36      15.2    6.74
# 53      14.4    6.67
# 105     14.1    6.86
# 61       9.0    7.10
# 28      15.7    6.98
# 111     17.8    6.65
# 69      16.9    6.33
# 4       16.9    6.65
# 137     13.6    6.70
# 134     12.2    6.78
# 145     11.9    7.12
# 93      11.1    6.69
# 64       3.5    7.19
# 78      14.2    6.82
# 87      14.5    6.51
# 117     15.8    7.17
# 10      15.4    6.43
# 75      15.8    6.03
# 32      13.1    6.81
# 41      14.7    5.38
# 95      14.8    7.05
# 20      13.1    6.32
# 6       21.9    6.40
# 19      16.6    6.29
# 23      16.1    6.83
# 130     17.7    6.49
#
# [30 rows x 35 columns]

# %% [markdown]
# ## Putting dataset through a Linear Regression model
# Apps field is removed due to high correlation with minutesPlayed
#
# Name and team field is removed since they have no relationship with a player's rating

# %%
from sklearn.linear_model import LinearRegression

input_columns = ['90s','GA','PKA','FK','CK', 'OG', 'PSxG', 'PSxG/SoT', 'PSxG+/-', '/90', 'Cmp',
                 'LaunchedAtt', 'Cmp%', 'PassesAtt', 'Thr', 'PassesLaunch%', 'PassesAvgLen', 'GoalKicksAtt',
                  'GoalKicksLaunch%', 'GoalKicksAvgLen', 'Opp', 'Stp', 'Stp%', '#OPA', '#OPA/90', 'AvgDist']
output_column = ['rating']

X_train = train[input_columns]
Y_train = train[output_column]
X_test = test[input_columns]
Y_test = test[output_column]

model = LinearRegression()
model.fit(X_train, Y_train)
print('Test R^2     : %.3f'%model.score(X_test, Y_test))
print('Training R^2 : %.3f'%model.score(X_train, Y_train))
# Out:
# Test R^2     : 0.718
# Training R^2 : 0.704

# %% [markdown]
# ## Try to apply the model on the whole dataset to predict Yashin Trophy winner

# %%
X_dataset = dataset[input_columns]
Y_preds = model.predict(X_dataset)
dataset['preds'] = Y_preds

yashin_winner = dataset.sort_values(['preds'],ascending=False)[:10]
print(yashin_winner[['Player', 'rating', 'preds']])
# Out:
#                     Player  rating     preds
# 107           Ørjan Nyland    6.87  7.001991
# 64        Joaquín Blázquez    7.19  6.972833
# 16           Asmir Begović    7.82  6.913636
# 25           Claudio Bravo    6.93  6.759987
# 62             Jeroen Zoet    6.35  6.721558
# 57               Ivo Grbić    6.73  6.684747
# 119              Rémy Riou    6.38  6.656208
# 131           Sven Ulreich    6.78  6.637964
# 84   Marc-André ter Stegen    6.87  6.596326
# 112             Pepe Reina    6.81  6.594868
# c:\Python310\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
