# %% [markdown]
# ## Reading the dataset

# %%
import numpy as np
import pandas as pd

#Reading the dataset
dataset = pd.read_excel("../GK-data.xlsx")

# %% [markdown]
# ## Spliting dataset into train set and test set

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(dataset, test_size=0.2)
print("Train set:\n", train)
print("Test set:\n", test)
# Out:
# Train set:
#        Rk            Player   Nation Pos        Squad                Comp  \
# 143  138       Yann Sommer   ch SUI  GK   M'Gladbach       de Bundesliga
# 89   140  Marco Sportiello   it ITA  GK     Atalanta          it Serie A
# 50    63      Gregor Kobel   ch SUI  GK     Dortmund       de Bundesliga
# 125  132         Rui Silva   pt POR  GK        Betis          es La Liga
# 52    99   Guillermo Ochoa   mx MEX  GK  Salernitana          it Serie A
# ..   ...               ...      ...  ..          ...                 ...
# 142   45      Yahia Fofana   fr FRA  GK       Angers          fr Ligue 1
# 93    34   Marko Dmitrović   rs SRB  GK      Sevilla          es La Liga
# 32     1     Doğan Alemdar   tr TUR  GK       Rennes          fr Ligue 1
# 0    115    Aaron Ramsdale  eng ENG  GK      Arsenal  eng Premier League
# 127    5     Sergio Asenjo   es ESP  GK   Valladolid          es La Liga
#
#         Age  Born   90s  GA  ...  GoalKicksAtt  GoalKicksLaunch%  \
# 143  34-032  1988  10.0  14  ...            90              24.4
# 89   30-253  1992   6.9   9  ...            61              68.9
# 50   25-043  1997  11.0  13  ...            76              40.8
# 125  28-345  1994  14.0  12  ...           120              66.7
# 52   37-189  1985   3.0  11  ...            21              61.9
# ..      ...   ...   ...  ..  ...           ...               ...
# 142  22-150  2000   8.0  15  ...            53              49.1
# 93   30-359  1992   2.5   3  ...            18              55.6
# 32   20-081  2002   2.5   4  ...            19              52.6
# 0    24-249  1998  18.0  14  ...            73              67.1
# 127  33-204  1989   5.0   7  ...            49              71.4
#
#      GoalKicksAvgLen  Opp  Stp  Stp%  #OPA  #OPA/90  AvgDist  rating
# 143             28.6  162    5   3.1    13     1.30     14.6    7.13
# 89              48.9   86    7   8.1    14     2.02     19.9    6.28
# 50              38.9  139    6   4.3    17     1.55     16.8    6.76
# 125             49.5  193   10   5.2    24     1.71     16.6    6.74
# 52              47.7   38    1   2.6     4     1.33     17.8    7.16
# ..               ...  ...  ...   ...   ...      ...      ...     ...
# 142             41.0  105   11  10.5     5     0.63     12.0    6.54
# 93              51.0   35    6  17.1     3     1.20     11.1    6.69
# 32              42.0   40    2   5.0     3     1.20     13.1    6.81
# 0               53.8  200   12   6.0    19     1.06     14.6    6.80
# 127             52.6   77    2   2.6    13     2.60     18.9    5.83
#
# [117 rows x 35 columns]
# Test set:
#        Rk                     Player   Nation Pos            Squad  \
# 12    26            Andrea Consigli   it ITA  GK         Sassuolo
# 34     7                Édgar Badía   es ESP  GK            Elche
# 64    15           Joaquín Blázquez   ar ARG  GK            Brest
# 8    129         Alexander Schwolow   de GER  GK       Schalke 04
# 71   127          Kasper Schmeichel   dk DEN  GK             Nice
# 81   136           Łukasz Skorupski   pl POL  GK          Bologna
# 95    70                Mateusz Lis   pl POL  GK           Troyes
# 129   79             Steve Mandanda   fr FRA  GK           Rennes
# 85    18               Marcin Bułka   pl POL  GK             Nice
# 47   106            Gianluca Pegolo   it ITA  GK         Sassuolo
# 57    52                  Ivo Grbić   hr CRO  GK  Atlético Madrid
# 101   77               Mike Maignan   fr FRA  GK            Milan
# 123   13               Rubén Blanco   es ESP  GK        Marseille
# 120  126             Robert Sánchez   es ESP  GK         Brighton
# 66   109            Jordan Pickford  eng ENG  GK          Everton
# 78   131                 Luigi Sepe   it ITA  GK      Salernitana
# 116  114           Predrag Rajković   rs SRB  GK         Mallorca
# 83   119             Manuel Riemann   de GER  GK           Bochum
# 2     41            Aitor Fernández   es ESP  GK          Osasuna
# 141  141          Wojciech Szczęsny   pl POL  GK         Juventus
# 41   137  François-Joseph Sollacaro   fr FRA  GK          Ajaccio
# 11   102                André Onana   cm CMR  GK            Inter
# 88   133            Marco Silvestri   it ITA  GK          Udinese
# 144   16             Yassine Bounou   ma MAR  GK          Sevilla
# 42    46             Fraser Forster  eng ENG  GK        Tottenham
# 96    21             Matis Carvalho   pt POR  GK      Montpellier
# 91    44               Mark Flekken   nl NED  GK         Freiburg
# 21    68                 Bernd Leno   de GER  GK           Fulham
# 105    8             Oliver Baumann   de GER  GK       Hoffenheim
# 9      2                    Alisson   br BRA  GK        Liverpool
#
#                    Comp     Age  Born   90s  GA  ...  GoalKicksAtt  \
# 12           it Serie A  35-356  1987  17.0  26  ...           157
# 34           es La Liga  30-340  1992  17.0  35  ...           130
# 64           fr Ligue 1  21-355  2001   1.0   0  ...            11
# 8         de Bundesliga  30-230  1992  15.0  32  ...           122
# 71           fr Ligue 1  36-074  1986  17.0  18  ...           139
# 81           it Serie A  31-258  1991  18.0  29  ...           129
# 95           fr Ligue 1  25-325  1997   7.0  14  ...            65
# 129          fr Ligue 1  37-296  1985  16.5  16  ...            84
# 85           fr Ligue 1  23-106  1999   2.0   2  ...            18
# 47           it Serie A  41-299  1981   1.0   2  ...            10
# 57           es La Liga  27-000  1996   2.3   2  ...            23
# 101          it Serie A  27-199  1995   7.0   8  ...            18
# 123          fr Ligue 1  27-177  1995   3.0   4  ...            28
# 120  eng Premier League  25-061  1997  18.0  25  ...           112
# 66   eng Premier League  28-317  1994  18.0  26  ...           159
# 78           it Serie A  31-255  1991  15.0  24  ...           134
# 116          es La Liga  27-079  1995  17.0  16  ...           162
# 83        de Bundesliga  34-131  1988  15.0  36  ...           117
# 2            es La Liga  31-260  1991   7.0   5  ...            50
# 141          it Serie A  32-275  1990  11.5   8  ...            54
# 41           fr Ligue 1  28-303  1994   1.0   3  ...             3
# 11           it Serie A  26-291  1996  10.0  11  ...            74
# 88           it Serie A  31-322  1991  18.0  21  ...           146
# 144          es La Liga  31-288  1991  14.5  23  ...           102
# 42   eng Premier League  34-307  1988   1.0   2  ...             5
# 96           fr Ligue 1  23-265  1999   1.5   3  ...            14
# 91        de Bundesliga  29-219  1993  15.0  17  ...           101
# 21   eng Premier League  30-320  1992  18.0  27  ...           125
# 105       de Bundesliga  32-230  1990  15.0  22  ...           103
# 9    eng Premier League  30-108  1992  18.0  25  ...            90
#
#      GoalKicksLaunch%  GoalKicksAvgLen  Opp  Stp  Stp%  #OPA  #OPA/90  \
# 12               31.8             33.3  220   13   5.9    15     0.88
# 34               56.9             43.3  255    9   3.5     5     0.29
# 64               18.2             26.3   11    2  18.2     0     0.00
# 8                78.7             58.0  242    6   2.5    15     1.00
# 71               39.6             35.8  236   10   4.2     8     0.47
# 81               37.2             33.6  254   16   6.3    17     0.94
# 95               40.0             34.1  129   10   7.8    11     1.57
# 129              66.7             45.2  185   17   9.2    19     1.15
# 85               55.6             44.2   26    2   7.7     3     1.50
# 47               20.0             24.0    6    0   0.0     0     0.00
# 57               95.7             67.0   43    7  16.3     0     0.00
# 101              38.9             40.4   65    5   7.7     6     0.86
# 123              42.9             35.5   45    0   0.0     4     1.33
# 120              42.9             38.4  188   15   8.0    11     0.61
# 66               67.9             51.2  277    8   2.9    26     1.44
# 78               46.3             40.6  199   15   7.5    11     0.73
# 116              66.0             48.8  271   11   4.1    10     0.59
# 83               68.4             51.3  217   13   6.0    57     3.80
# 2                70.0             51.7   89    4   4.5    13     1.86
# 141              46.3             41.9  144    4   2.8     6     0.52
# 41                0.0             23.0   10    0   0.0     0     0.00
# 11               37.8             38.9  142    6   4.2     3     0.30
# 88               39.0             36.4  235    4   1.7     9     0.50
# 144              49.0             41.8  196   13   6.6    30     2.07
# 42               60.0             39.4   10    0   0.0     2     2.00
# 96               92.9             61.4   38    2   5.3     0     0.00
# 91               70.3             55.6  174   12   6.9    24     1.60
# 21               39.2             35.8  232   20   8.6    23     1.28
# 105              17.5             25.0  178   20  11.2    21     1.40
# 9                23.3             30.9  202    6   3.0    36     2.00
#
#      AvgDist  rating
# 12      14.5    6.38
# 34      11.2    6.65
# 64       3.5    7.19
# 8       14.8    6.44
# 71      12.2    6.63
# 81      14.3    6.64
# 95      14.8    7.05
# 129     15.2    6.63
# 85      13.8    6.26
# 47      13.0    5.81
# 57       5.5    6.73
# 101     12.9    6.75
# 123     20.3    6.32
# 120     12.7    6.56
# 66      15.7    6.83
# 78      14.2    6.82
# 116     12.4    6.65
# 83      22.4    6.68
# 2       16.4    6.82
# 141     13.5    6.94
# 41      14.7    5.38
# 11      14.2    6.65
# 88      13.8    6.53
# 144     18.5    6.60
# 42      20.7    6.35
# 96       8.3    6.30
# 91      16.0    6.88
# 21      14.2    7.15
# 105     14.1    6.86
# 9       20.2    6.97
#
# [30 rows x 35 columns]

# %% [markdown]
# ## Putting dataset through a Linear Regression model
# Apps field is removed due to high correlation with minutesPlayed
#
# Name and team field is removed since they have no relationship with a player's rating

# %%
from sklearn.ensemble import RandomForestRegressor

input_columns = ['90s','GA','PKA','FK','CK', 'OG', 'PSxG', 'PSxG/SoT', 'PSxG+/-', '/90', 'Cmp',
                 'LaunchedAtt', 'Cmp%', 'PassesAtt', 'Thr', 'PassesLaunch%', 'PassesAvgLen', 'GoalKicksAtt',
                  'GoalKicksLaunch%', 'GoalKicksAvgLen', 'Opp', 'Stp', 'Stp%', '#OPA', '#OPA/90', 'AvgDist']
output_column = ['rating']

X_train = train[input_columns]
Y_train = train[output_column]
X_test = test[input_columns]
Y_test = test[output_column]

model = RandomForestRegressor(n_estimators = 10, random_state = 0)
model.fit(X_train, Y_train)
print('Test R^2     : %.3f'%model.score(X_test, Y_test))
print('Training R^2 : %.3f'%model.score(X_train, Y_train))
# Out:
# Test R^2     : 0.673
# Training R^2 : 0.865
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6792\2406957588.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, Y_train)

# %% [markdown]
# ## Try to apply the model on the whole dataset to predict Yashin Trophy winner

# %%
X_dataset = dataset[input_columns]
Y_preds = model.predict(X_dataset)
dataset['preds'] = Y_preds

yashin_winner = dataset.sort_values(['preds'],ascending=False)[:10]
print(yashin_winner[['Player', 'rating', 'preds']])
# Out:
#                 Player  rating  preds
# 16       Asmir Begović    7.82  7.354
# 64    Joaquín Blázquez    7.19  7.319
# 57           Ivo Grbić    6.73  7.168
# 143        Yann Sommer    7.13  7.105
# 145      Yehvann Diouf    7.12  7.098
# 117    Rafał Gikiewicz    7.17  7.096
# 46      Gerónimo Rulli    7.14  7.095
# 107       Ørjan Nyland    6.87  7.060
# 72   Kepa Arrizabalaga    7.16  7.034
# 67         Jordi Masip    7.00  6.989
